# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/music-test/music_test/S1m40_03.png
# /kaggle/input/music-test/music_test/S1m21_05.png
# /kaggle/input/music-test/music_test/S1m12_06.png
# /kaggle/input/music-test/music_test/S1m61_02.png
# /kaggle/input/music-test/music_test/S1m39_05.png
# /kaggle/input/music-test/music_test/S1m20_00.png
# /kaggle/input/music-test/music_test/S1m67_07.png
# /kaggle/input/music-test/music_test/S1m52_04.png
# /kaggle/input/music-test/music_test/S1m21_07.png
# /kaggle/input/music-test/music_test/S1m28_06.png
# /kaggle/input/music-test/music_test/S1m73_04.png
# /kaggle/input/music-test/music_test/S1m25_00.png
# /kaggle/input/music-test/music_test/S1m34_07.png
# /kaggle/input/music-test/music_test/S1m04_06.png
# /kaggle/input/music-test/music_test/S1m78_05.png
# /kaggle/input/music-test/music_test/S1m70_04.png
# /kaggle/input/music-test/music_test/S1m74_05.png
# /kaggle/input/music-test/music_test/S1m07_07.png
# /kaggle/input/music-test/music_test/S1m20_06.png
# /kaggle/input/music-test/music_test/S1m10_00.png
# /kaggle/input/music-test/music_test/S1m16_05.png
# /kaggle/input/music-test/music_test/S1m55_01.png
# /kaggle/input/music-test/music_test/S1m44_00.png
# /kaggle/input/music-test/music_test/S1m32_06.png
# /kaggle/input/music-test/music_test/S1m60_02.png
# /kaggle/input/music-test/music_test/S1m51_04.png
# /kaggle/input/music-test/music_test/S1m49_02.png
# /kaggle/input/music-test/music_test/S1m33_05.png
# /kaggle/input/music-test/music_test/S1m59_00.png
# /kaggle/input/music-test/music_test/S1m67_05.png
# /kaggle/input/music-test/music_test/S1m61_00.png
# /kaggle/input/music-test/music_test/S1m58_03.png
# /kaggle/input/music-test/music_test/S1m48_01.png
# /kaggle/input/music-test/music_test/S1m01_03.png
# /kaggle/input/music-test/music_test/S1m48_05.png
# /kaggle/input/music-test/music_test/S1m54_03.png
# /kaggle/input/music-test/music_test/S1m67_04.png
# /kaggle/input/music-test/music_test/S1m19_04.png
# /kaggle/input/music-test/music_test/S1m29_04.png
# /kaggle/input/music-test/music_test/S1m45_06.png
# /kaggle/input/music-test/music_test/S1m26_00.png
# /kaggle/input/music-test/music_test/S1m14_06.png
# /kaggle/input/music-test/music_test/S1m56_02.png
# /kaggle/input/music-test/music_test/S1m69_04.png
# /kaggle/input/music-test/music_test/S1m03_01.png
# /kaggle/input/music-test/music_test/S1m33_06.png
# /kaggle/input/music-test/music_test/S1m72_00.png
# /kaggle/input/music-test/music_test/S1m68_07.png
# /kaggle/input/music-test/music_test/S1m73_01.png
# /kaggle/input/music-test/music_test/S1m74_07.png
# /kaggle/input/music-test/music_test/S1m51_05.png
# /kaggle/input/music-test/music_test/S1m78_00.png
# /kaggle/input/music-test/music_test/S1m22_04.png
# /kaggle/input/music-test/music_test/S1m60_01.png
# /kaggle/input/music-test/music_test/S1m70_07.png
# /kaggle/input/music-test/music_test/S1m65_07.png
# /kaggle/input/music-test/music_test/S1m15_02.png
# /kaggle/input/music-test/music_test/S1m76_01.png
# /kaggle/input/music-test/music_test/S1m54_04.png
# /kaggle/input/music-test/music_test/S1m39_04.png
# /kaggle/input/music-test/music_test/S1m56_05.png
# /kaggle/input/music-test/music_test/S1m09_06.png
# /kaggle/input/music-test/music_test/S1m31_04.png
# /kaggle/input/music-test/music_test/S1m32_01.png
# /kaggle/input/music-test/music_test/S1m74_06.png
# /kaggle/input/music-test/music_test/S1m01_07.png
# /kaggle/input/music-test/music_test/S1m40_05.png
# /kaggle/input/music-test/music_test/S1m10_05.png
# /kaggle/input/music-test/music_test/S1m71_07.png
# /kaggle/input/music-test/music_test/S1m18_01.png
# /kaggle/input/music-test/music_test/S1m64_07.png
# /kaggle/input/music-test/music_test/S1m41_02.png
# /kaggle/input/music-test/music_test/S1m03_07.png
# /kaggle/input/music-test/music_test/S1m68_06.png
# /kaggle/input/music-test/music_test/S1m54_05.png
# /kaggle/input/music-test/music_test/S1m66_01.png
# /kaggle/input/music-test/music_test/S1m73_00.png
# /kaggle/input/music-test/music_test/S1m38_02.png
# /kaggle/input/music-test/music_test/S1m42_03.png
# /kaggle/input/music-test/music_test/S1m77_04.png
# /kaggle/input/music-test/music_test/S1m21_02.png
# /kaggle/input/music-test/music_test/S1m05_05.png
# /kaggle/input/music-test/music_test/S1m17_05.png
# /kaggle/input/music-test/music_test/S1m47_02.png
# /kaggle/input/music-test/music_test/S1m71_05.png
# /kaggle/input/music-test/music_test/S1m19_00.png
# /kaggle/input/music-test/music_test/S1m55_07.png
# /kaggle/input/music-test/music_test/S1m52_07.png
# /kaggle/input/music-test/music_test/S1m40_02.png
# /kaggle/input/music-test/music_test/S1m60_00.png
# /kaggle/input/music-test/music_test/S1m65_05.png
# /kaggle/input/music-test/music_test/S1m47_06.png
# /kaggle/input/music-test/music_test/S1m41_03.png
# /kaggle/input/music-test/music_test/S1m27_04.png
# /kaggle/input/music-test/music_test/S1m42_05.png
# /kaggle/input/music-test/music_test/S1m17_02.png
# /kaggle/input/music-test/music_test/S1m17_00.png
# /kaggle/input/music-test/music_test/S1m51_07.png
# /kaggle/input/music-test/music_test/S1m59_02.png
# /kaggle/input/music-test/music_test/S1m75_03.png
# /kaggle/input/music-test/music_test/S1m27_00.png
# /kaggle/input/music-test/music_test/S1m55_04.png
# /kaggle/input/music-test/music_test/S1m09_01.png
# /kaggle/input/music-test/music_test/S1m29_07.png
# /kaggle/input/music-test/music_test/S1m40_04.png
# /kaggle/input/music-test/music_test/S1m50_05.png
# /kaggle/input/music-test/music_test/S1m07_04.png
# /kaggle/input/music-test/music_test/S1m34_05.png
# /kaggle/input/music-test/music_test/S1m27_01.png
# /kaggle/input/music-test/music_test/S1m66_03.png
# /kaggle/input/music-test/music_test/S1m23_01.png
# /kaggle/input/music-test/music_test/S1m06_07.png
# /kaggle/input/music-test/music_test/S1m44_02.png
# /kaggle/input/music-test/music_test/S1m15_05.png
# /kaggle/input/music-test/music_test/S1m39_06.png
# /kaggle/input/music-test/music_test/S1m22_07.png
# /kaggle/input/music-test/music_test/S1m21_06.png
# /kaggle/input/music-test/music_test/S1m28_07.png
# /kaggle/input/music-test/music_test/S1m13_01.png
# /kaggle/input/music-test/music_test/S1m37_03.png
# /kaggle/input/music-test/music_test/S1m38_07.png
# /kaggle/input/music-test/music_test/S1m27_03.png
# /kaggle/input/music-test/music_test/S1m08_04.png
# /kaggle/input/music-test/music_test/S1m10_06.png
# /kaggle/input/music-test/music_test/S1m11_01.png
# /kaggle/input/music-test/music_test/S1m58_05.png
# /kaggle/input/music-test/music_test/S1m11_06.png
# /kaggle/input/music-test/music_test/S1m67_00.png
# /kaggle/input/music-test/music_test/S1m77_05.png
# /kaggle/input/music-test/music_test/S1m36_07.png
# /kaggle/input/music-test/music_test/S1m13_07.png
# /kaggle/input/music-test/music_test/S1m06_05.png
# /kaggle/input/music-test/music_test/S1m63_04.png
# /kaggle/input/music-test/music_test/S1m11_03.png
# /kaggle/input/music-test/music_test/S1m22_00.png
# /kaggle/input/music-test/music_test/S1m38_06.png
# /kaggle/input/music-test/music_test/S1m41_04.png
# /kaggle/input/music-test/music_test/S1m25_01.png
# /kaggle/input/music-test/music_test/S1m79_01.png
# /kaggle/input/music-test/music_test/S1m57_07.png
# /kaggle/input/music-test/music_test/S1m68_02.png
# /kaggle/input/music-test/music_test/S1m73_06.png
# /kaggle/input/music-test/music_test/S1m26_04.png
# /kaggle/input/music-test/music_test/S1m10_03.png
# /kaggle/input/music-test/music_test/S1m13_06.png
# /kaggle/input/music-test/music_test/S1m73_05.png
# /kaggle/input/music-test/music_test/S1m24_03.png
# /kaggle/input/music-test/music_test/S1m36_00.png
# /kaggle/input/music-test/music_test/S1m66_04.png
# /kaggle/input/music-test/music_test/S1m17_06.png
# /kaggle/input/music-test/music_test/S1m45_00.png
# /kaggle/input/music-test/music_test/S1m03_05.png
# /kaggle/input/music-test/music_test/S1m34_06.png
# /kaggle/input/music-test/music_test/S1m69_00.png
# /kaggle/input/music-test/music_test/S1m61_04.png
# /kaggle/input/music-test/music_test/S1m12_03.png
# /kaggle/input/music-test/music_test/S1m63_00.png
# /kaggle/input/music-test/music_test/S1m22_06.png
# /kaggle/input/music-test/music_test/S1m78_03.png
# /kaggle/input/music-test/music_test/S1m22_02.png
# /kaggle/input/music-test/music_test/S1m12_02.png
# /kaggle/input/music-test/music_test/S1m11_05.png
# /kaggle/input/music-test/music_test/S1m17_07.png
# /kaggle/input/music-test/music_test/S1m44_04.png
# /kaggle/input/music-test/music_test/S1m36_01.png
# /kaggle/input/music-test/music_test/S1m20_04.png
# /kaggle/input/music-test/music_test/S1m45_05.png
# /kaggle/input/music-test/music_test/S1m77_02.png
# /kaggle/input/music-test/music_test/S1m43_03.png
# /kaggle/input/music-test/music_test/S1m54_07.png
# /kaggle/input/music-test/music_test/S1m76_02.png
# /kaggle/input/music-test/music_test/S1m77_00.png
# /kaggle/input/music-test/music_test/S1m18_05.png
# /kaggle/input/music-test/music_test/S1m01_05.png
# /kaggle/input/music-test/music_test/S1m11_00.png
# /kaggle/input/music-test/music_test/S1m66_05.png
# /kaggle/input/music-test/music_test/S1m57_01.png
# /kaggle/input/music-test/music_test/S1m42_01.png
# /kaggle/input/music-test/music_test/S1m47_07.png
# /kaggle/input/music-test/music_test/S1m50_03.png
# /kaggle/input/music-test/music_test/S1m37_06.png
# /kaggle/input/music-test/music_test/S1m52_05.png
# /kaggle/input/music-test/music_test/S1m17_01.png
# /kaggle/input/music-test/music_test/S1m22_05.png
# /kaggle/input/music-test/music_test/S1m57_06.png
# /kaggle/input/music-test/music_test/S1m38_01.png
# /kaggle/input/music-test/music_test/S1m27_06.png
# /kaggle/input/music-test/music_test/S1m43_05.png
# /kaggle/input/music-test/music_test/S1m58_04.png
# /kaggle/input/music-test/music_test/S1m29_05.png
# /kaggle/input/music-test/music_test/S1m08_05.png
# /kaggle/input/music-test/music_test/S1m53_01.png
# /kaggle/input/music-test/music_test/S1m13_03.png
# /kaggle/input/music-test/music_test/S1m06_00.png
# /kaggle/input/music-test/music_test/S1m37_04.png
# /kaggle/input/music-test/music_test/S1m72_05.png
# /kaggle/input/music-test/music_test/S1m76_05.png
# /kaggle/input/music-test/music_test/S1m26_05.png
# /kaggle/input/music-test/music_test/S1m75_07.png
# /kaggle/input/music-test/music_test/S1m79_00.png
# /kaggle/input/music-test/music_test/S1m64_03.png
# /kaggle/input/music-test/music_test/S1m61_06.png
# /kaggle/input/music-test/music_test/S1m19_05.png
# /kaggle/input/music-test/music_test/S1m31_06.png
# /kaggle/input/music-test/music_test/S1m18_00.png
# /kaggle/input/music-test/music_test/S1m05_00.png
# /kaggle/input/music-test/music_test/S1m45_02.png
# /kaggle/input/music-test/music_test/S1m79_02.png
# /kaggle/input/music-test/music_test/S1m49_07.png
# /kaggle/input/music-test/music_test/S1m53_00.png
# /kaggle/input/music-test/music_test/S1m04_05.png
# /kaggle/input/music-test/music_test/S1m03_04.png
# /kaggle/input/music-test/music_test/S1m14_05.png
# /kaggle/input/music-test/music_test/S1m05_06.png
# /kaggle/input/music-test/music_test/S1m65_04.png
# /kaggle/input/music-test/music_test/S1m06_03.png
# /kaggle/input/music-test/music_test/S1m43_01.png
# /kaggle/input/music-test/music_test/S1m02_07.png
# /kaggle/input/music-test/music_test/S1m02_05.png
# /kaggle/input/music-test/music_test/S1m21_03.png
# /kaggle/input/music-test/music_test/S1m35_01.png
# /kaggle/input/music-test/music_test/S1m69_07.png
# /kaggle/input/music-test/music_test/S1m21_01.png
# /kaggle/input/music-test/music_test/S1m19_01.png
# /kaggle/input/music-test/music_test/S1m47_00.png
# /kaggle/input/music-test/music_test/S1m32_07.png
# /kaggle/input/music-test/music_test/S1m54_01.png
# /kaggle/input/music-test/music_test/S1m49_00.png
# /kaggle/input/music-test/music_test/S1m61_01.png
# /kaggle/input/music-test/music_test/S1m01_06.png
# /kaggle/input/music-test/music_test/S1m66_07.png
# /kaggle/input/music-test/music_test/S1m13_02.png
# /kaggle/input/music-test/music_test/S1m48_02.png
# /kaggle/input/music-test/music_test/S1m19_02.png
# /kaggle/input/music-test/music_test/S1m64_06.png
# /kaggle/input/music-test/music_test/S1m48_07.png
# /kaggle/input/music-test/music_test/S1m09_02.png
# /kaggle/input/music-test/music_test/S1m10_01.png
# /kaggle/input/music-test/music_test/S1m72_01.png
# /kaggle/input/music-test/music_test/S1m30_00.png
# /kaggle/input/music-test/music_test/S1m33_00.png
# /kaggle/input/music-test/music_test/S1m24_02.png
# /kaggle/input/music-test/music_test/S1m52_01.png
# /kaggle/input/music-test/music_test/S1m19_07.png
# /kaggle/input/music-test/music_test/S1m16_00.png
# /kaggle/input/music-test/music_test/S1m15_07.png
# /kaggle/input/music-test/music_test/S1m25_07.png
# /kaggle/input/music-test/music_test/S1m63_02.png
# /kaggle/input/music-test/music_test/S1m70_05.png
# /kaggle/input/music-test/music_test/S1m10_07.png
# /kaggle/input/music-test/music_test/S1m04_03.png
# /kaggle/input/music-test/music_test/S1m73_03.png
# /kaggle/input/music-test/music_test/S1m16_02.png
# /kaggle/input/music-test/music_test/S1m62_05.png
# /kaggle/input/music-test/music_test/S1m06_04.png
# /kaggle/input/music-test/music_test/S1m78_01.png
# /kaggle/input/music-test/music_test/S1m34_01.png
# /kaggle/input/music-test/music_test/S1m42_00.png
# /kaggle/input/music-test/music_test/S1m28_00.png
# /kaggle/input/music-test/music_test/S1m46_07.png
# /kaggle/input/music-test/music_test/S1m55_06.png
# /kaggle/input/music-test/music_test/S1m20_03.png
# /kaggle/input/music-test/music_test/S1m63_03.png
# /kaggle/input/music-test/music_test/S1m47_05.png
# /kaggle/input/music-test/music_test/S1m24_01.png
# /kaggle/input/music-test/music_test/S1m37_07.png
# /kaggle/input/music-test/music_test/S1m74_01.png
# /kaggle/input/music-test/music_test/S1m71_03.png
# /kaggle/input/music-test/music_test/S1m46_01.png
# /kaggle/input/music-test/music_test/S1m55_00.png
# /kaggle/input/music-test/music_test/S1m55_02.png
# /kaggle/input/music-test/music_test/S1m23_07.png
# /kaggle/input/music-test/music_test/S1m64_05.png
# /kaggle/input/music-test/music_test/S1m36_04.png
# /kaggle/input/music-test/music_test/S1m68_03.png
# /kaggle/input/music-test/music_test/S1m77_03.png
# /kaggle/input/music-test/music_test/S1m41_06.png
# /kaggle/input/music-test/music_test/S1m08_03.png
# /kaggle/input/music-test/music_test/S1m56_07.png
# /kaggle/input/music-test/music_test/S1m63_05.png
# /kaggle/input/music-test/music_test/S1m39_03.png
# /kaggle/input/music-test/music_test/S1m14_00.png
# /kaggle/input/music-test/music_test/S1m53_06.png
# /kaggle/input/music-test/music_test/S1m78_07.png
# /kaggle/input/music-test/music_test/S1m28_04.png
# /kaggle/input/music-test/music_test/S1m40_01.png
# /kaggle/input/music-test/music_test/S1m37_01.png
# /kaggle/input/music-test/music_test/S1m44_06.png
# /kaggle/input/music-test/music_test/S1m60_07.png
# /kaggle/input/music-test/music_test/S1m76_06.png
# /kaggle/input/music-test/music_test/S1m38_03.png
# /kaggle/input/music-test/music_test/S1m29_03.png
# /kaggle/input/music-test/music_test/S1m59_05.png
# /kaggle/input/music-test/music_test/S1m58_06.png
# /kaggle/input/music-test/music_test/S1m18_06.png
# /kaggle/input/music-test/music_test/S1m14_03.png
# /kaggle/input/music-test/music_test/S1m38_00.png
# /kaggle/input/music-test/music_test/S1m11_02.png
# /kaggle/input/music-test/music_test/S1m50_01.png
# /kaggle/input/music-test/music_test/S1m06_02.png
# /kaggle/input/music-test/music_test/S1m39_07.png
# /kaggle/input/music-test/music_test/S1m48_00.png
# /kaggle/input/music-test/music_test/S1m53_03.png
# /kaggle/input/music-test/music_test/S1m11_04.png
# /kaggle/input/music-test/music_test/S1m40_06.png
# /kaggle/input/music-test/music_test/S1m57_04.png
# /kaggle/input/music-test/music_test/S1m63_07.png
# /kaggle/input/music-test/music_test/S1m32_00.png
# /kaggle/input/music-test/music_test/S1m65_01.png
# /kaggle/input/music-test/music_test/S1m24_00.png
# /kaggle/input/music-test/music_test/S1m68_05.png
# /kaggle/input/music-test/music_test/S1m58_01.png
# /kaggle/input/music-test/music_test/S1m53_05.png
# /kaggle/input/music-test/music_test/S1m56_06.png
# /kaggle/input/music-test/music_test/S1m49_04.png
# /kaggle/input/music-test/music_test/S1m34_04.png
# /kaggle/input/music-test/music_test/S1m70_01.png
# /kaggle/input/music-test/music_test/S1m08_01.png
# /kaggle/input/music-test/music_test/S1m75_06.png
# /kaggle/input/music-test/music_test/S1m47_03.png
# /kaggle/input/music-test/music_test/S1m53_07.png
# /kaggle/input/music-test/music_test/S1m46_03.png
# /kaggle/input/music-test/music_test/S1m69_06.png
# /kaggle/input/music-test/music_test/S1m25_05.png
# /kaggle/input/music-test/music_test/S1m25_02.png
# /kaggle/input/music-test/music_test/S1m71_01.png
# /kaggle/input/music-test/music_test/S1m51_00.png
# /kaggle/input/music-test/music_test/S1m75_05.png
# /kaggle/input/music-test/music_test/S1m39_00.png
# /kaggle/input/music-test/music_test/S1m02_00.png
# /kaggle/input/music-test/music_test/S1m17_04.png
# /kaggle/input/music-test/music_test/S1m23_04.png
# /kaggle/input/music-test/music_test/S1m32_04.png
# /kaggle/input/music-test/music_test/S1m60_06.png
# /kaggle/input/music-test/music_test/S1m25_03.png
# /kaggle/input/music-test/music_test/S1m10_02.png
# /kaggle/input/music-test/music_test/S1m20_01.png
# /kaggle/input/music-test/music_test/S1m37_02.png
# /kaggle/input/music-test/music_test/S1m03_03.png
# /kaggle/input/music-test/music_test/S1m72_03.png
# /kaggle/input/music-test/music_test/S1m42_04.png
# /kaggle/input/music-test/music_test/S1m16_07.png
# /kaggle/input/music-test/music_test/S1m65_02.png
# /kaggle/input/music-test/music_test/S1m29_06.png
# /kaggle/input/music-test/music_test/S1m68_01.png
# /kaggle/input/music-test/music_test/S1m68_00.png
# /kaggle/input/music-test/music_test/S1m21_04.png
# /kaggle/input/music-test/music_test/S1m28_05.png
# /kaggle/input/music-test/music_test/S1m10_04.png
# /kaggle/input/music-test/music_test/S1m29_01.png
# /kaggle/input/music-test/music_test/S1m02_06.png
# /kaggle/input/music-test/music_test/S1m70_02.png
# /kaggle/input/music-test/music_test/S1m62_01.png
# /kaggle/input/music-test/music_test/S1m13_04.png
# /kaggle/input/music-test/music_test/S1m41_01.png
# /kaggle/input/music-test/music_test/S1m03_02.png
# /kaggle/input/music-test/music_test/S1m08_06.png
# /kaggle/input/music-test/music_test/S1m71_00.png
# /kaggle/input/music-test/music_test/S1m51_06.png
# /kaggle/input/music-test/music_test/S1m70_00.png
# /kaggle/input/music-test/music_test/S1m44_07.png
# /kaggle/input/music-test/music_test/S1m46_06.png
# /kaggle/input/music-test/music_test/S1m35_03.png
# /kaggle/input/music-test/music_test/S1m62_06.png
# /kaggle/input/music-test/music_test/S1m61_05.png
# /kaggle/input/music-test/music_test/S1m09_05.png
# /kaggle/input/music-test/music_test/S1m65_06.png
# /kaggle/input/music-test/music_test/S1m72_07.png
# /kaggle/input/music-test/music_test/S1m25_04.png
# /kaggle/input/music-test/music_test/S1m49_01.png
# /kaggle/input/music-test/music_test/S1m36_02.png
# /kaggle/input/music-test/music_test/S1m42_02.png
# /kaggle/input/music-test/music_test/S1m50_00.png
# /kaggle/input/music-test/music_test/S1m67_02.png
# /kaggle/input/music-test/music_test/S1m52_00.png
# /kaggle/input/music-test/music_test/S1m44_01.png
# /kaggle/input/music-test/music_test/S1m54_06.png
# /kaggle/input/music-test/music_test/S1m60_05.png
# /kaggle/input/music-test/music_test/S1m01_00.png
# /kaggle/input/music-test/music_test/S1m64_01.png
# /kaggle/input/music-test/music_test/S1m73_02.png
# /kaggle/input/music-test/music_test/S1m32_02.png
# /kaggle/input/music-test/music_test/S1m01_04.png
# /kaggle/input/music-test/music_test/S1m49_03.png
# /kaggle/input/music-test/music_test/S1m01_01.png
# /kaggle/input/music-test/music_test/S1m77_07.png
# /kaggle/input/music-test/music_test/S1m58_02.png
# /kaggle/input/music-test/music_test/S1m14_01.png
# /kaggle/input/music-test/music_test/S1m27_07.png
# /kaggle/input/music-test/music_test/S1m62_00.png
# /kaggle/input/music-test/music_test/S1m59_07.png
# /kaggle/input/music-test/music_test/S1m65_00.png
# /kaggle/input/music-test/music_test/S1m57_03.png
# /kaggle/input/music-test/music_test/S1m56_04.png
# /kaggle/input/music-test/music_test/S1m46_02.png
# /kaggle/input/music-test/music_test/S1m35_02.png
# /kaggle/input/music-test/music_test/S1m67_06.png
# /kaggle/input/music-test/music_test/S1m54_00.png
# /kaggle/input/music-test/music_test/S1m48_03.png
# /kaggle/input/music-test/music_test/S1m20_02.png
# /kaggle/input/music-test/music_test/S1m30_04.png
# /kaggle/input/music-test/music_test/S1m23_02.png
# /kaggle/input/music-test/music_test/S1m26_02.png
# /kaggle/input/music-test/music_test/S1m35_06.png
# /kaggle/input/music-test/music_test/S1m29_02.png
# /kaggle/input/music-test/music_test/S1m48_06.png
# /kaggle/input/music-test/music_test/S1m41_00.png
# /kaggle/input/music-test/music_test/S1m59_04.png
# /kaggle/input/music-test/music_test/S1m33_07.png
# /kaggle/input/music-test/music_test/S1m35_04.png
# /kaggle/input/music-test/music_test/S1m76_00.png
# /kaggle/input/music-test/music_test/S1m63_01.png
# /kaggle/input/music-test/music_test/S1m47_04.png
# /kaggle/input/music-test/music_test/S1m79_03.png
# /kaggle/input/music-test/music_test/S1m26_03.png
# /kaggle/input/music-test/music_test/S1m12_07.png
# /kaggle/input/music-test/music_test/S1m19_06.png
# /kaggle/input/music-test/music_test/S1m38_05.png
# /kaggle/input/music-test/music_test/S1m73_07.png
# /kaggle/input/music-test/music_test/S1m38_04.png
# /kaggle/input/music-test/music_test/S1m03_06.png
# /kaggle/input/music-test/music_test/S1m66_00.png
# /kaggle/input/music-test/music_test/S1m27_05.png
# /kaggle/input/music-test/music_test/S1m49_05.png
# /kaggle/input/music-test/music_test/S1m25_06.png
# /kaggle/input/music-test/music_test/S1m50_07.png
# /kaggle/input/music-test/music_test/S1m75_04.png
# /kaggle/input/music-test/music_test/S1m76_03.png
# /kaggle/input/music-test/music_test/S1m21_00.png
# /kaggle/input/music-test/music_test/S1m31_03.png
# /kaggle/input/music-test/music_test/S1m78_06.png
# /kaggle/input/music-test/music_test/S1m75_01.png
# /kaggle/input/music-test/music_test/S1m11_07.png
# /kaggle/input/music-test/music_test/S1m43_07.png
# /kaggle/input/music-test/music_test/S1m34_00.png
# /kaggle/input/music-test/music_test/S1m46_05.png
# /kaggle/input/music-test/music_test/S1m45_04.png
# /kaggle/input/music-test/music_test/S1m79_07.png
# /kaggle/input/music-test/music_test/S1m28_01.png
# /kaggle/input/music-test/music_test/S1m41_07.png
# /kaggle/input/music-test/music_test/S1m23_06.png
# /kaggle/input/music-test/music_test/S1m57_02.png
# /kaggle/input/music-test/music_test/S1m05_04.png
# /kaggle/input/music-test/music_test/S1m03_00.png
# /kaggle/input/music-test/music_test/S1m64_02.png
# /kaggle/input/music-test/music_test/S1m58_07.png
# /kaggle/input/music-test/music_test/S1m53_04.png
# /kaggle/input/music-test/music_test/S1m74_03.png
# /kaggle/input/music-test/music_test/S1m05_03.png
# /kaggle/input/music-test/music_test/S1m39_02.png
# /kaggle/input/music-test/music_test/S1m35_05.png
# /kaggle/input/music-test/music_test/S1m12_00.png
# /kaggle/input/music-test/music_test/S1m14_04.png
# /kaggle/input/music-test/music_test/S1m30_01.png
# /kaggle/input/music-test/music_test/S1m15_03.png
# /kaggle/input/music-test/music_test/S1m04_02.png
# /kaggle/input/music-test/music_test/S1m67_01.png
# /kaggle/input/music-test/music_test/S1m77_06.png
# /kaggle/input/music-test/music_test/S1m43_06.png
# /kaggle/input/music-test/music_test/S1m04_07.png
# /kaggle/input/music-test/music_test/S1m27_02.png
# /kaggle/input/music-test/music_test/S1m66_06.png
# /kaggle/input/music-test/music_test/S1m79_05.png
# /kaggle/input/music-test/music_test/S1m54_02.png
# /kaggle/input/music-test/music_test/S1m05_02.png
# /kaggle/input/music-test/music_test/S1m29_00.png
# /kaggle/input/music-test/music_test/S1m24_06.png
# /kaggle/input/music-test/music_test/S1m45_07.png
# /kaggle/input/music-test/music_test/S1m12_04.png
# /kaggle/input/music-test/music_test/S1m44_03.png
# /kaggle/input/music-test/music_test/S1m57_00.png
# /kaggle/input/music-test/music_test/S1m50_04.png
# /kaggle/input/music-test/music_test/S1m69_05.png
# /kaggle/input/music-test/music_test/S1m55_03.png
# /kaggle/input/music-test/music_test/S1m02_01.png
# /kaggle/input/music-test/music_test/S1m69_01.png
# /kaggle/input/music-test/music_test/S1m72_04.png
# /kaggle/input/music-test/music_test/S1m23_03.png
# /kaggle/input/music-test/music_test/S1m71_02.png
# /kaggle/input/music-test/music_test/S1m75_02.png
# /kaggle/input/music-test/music_test/S1m07_00.png
# /kaggle/input/music-test/music_test/S1m62_04.png
# /kaggle/input/music-test/music_test/S1m79_06.png
# /kaggle/input/music-test/music_test/S1m02_04.png
# /kaggle/input/music-test/music_test/S1m46_04.png
# /kaggle/input/music-test/music_test/S1m79_04.png
# /kaggle/input/music-test/music_test/S1m19_03.png
# /kaggle/input/music-test/music_test/S1m40_07.png
# /kaggle/input/music-test/music_test/S1m09_04.png
# /kaggle/input/music-test/music_test/S1m30_02.png
# /kaggle/input/music-test/music_test/S1m37_05.png
# /kaggle/input/music-test/music_test/S1m51_03.png
# /kaggle/input/music-test/music_test/S1m16_06.png
# /kaggle/input/music-test/music_test/S1m08_00.png
# /kaggle/input/music-test/music_test/S1m14_07.png
# /kaggle/input/music-test/music_test/S1m09_03.png
# /kaggle/input/music-test/music_test/S1m26_07.png
# /kaggle/input/music-test/music_test/S1m05_01.png
# /kaggle/input/music-test/music_test/S1m39_01.png
# /kaggle/input/music-test/music_test/S1m66_02.png
# /kaggle/input/music-test/music_test/S1m22_03.png
# /kaggle/input/music-test/music_test/S1m64_04.png
# /kaggle/input/music-test/music_test/S1m06_06.png
# /kaggle/input/music-test/music_test/S1m33_02.png
# /kaggle/input/music-test/music_test/S1m62_02.png
# /kaggle/input/music-test/music_test/S1m46_00.png
# /kaggle/input/music-test/music_test/S1m24_07.png
# /kaggle/input/music-test/music_test/S1m28_03.png
# /kaggle/input/music-test/music_test/S1m47_01.png
# /kaggle/input/music-test/music_test/S1m07_01.png
# /kaggle/input/music-test/music_test/S1m57_05.png
# /kaggle/input/music-test/music_test/S1m45_01.png
# /kaggle/input/music-test/music_test/S1m12_01.png
# /kaggle/input/music-test/music_test/S1m32_03.png
# /kaggle/input/music-test/music_test/S1m56_00.png
# /kaggle/input/music-test/music_test/S1m33_04.png
# /kaggle/input/music-test/music_test/S1m59_06.png
# /kaggle/input/music-test/music_test/S1m09_00.png
# /kaggle/input/music-test/music_test/S1m15_06.png
# /kaggle/input/music-test/music_test/S1m15_04.png
# /kaggle/input/music-test/music_test/S1m24_04.png
# /kaggle/input/music-test/music_test/S1m20_05.png
# /kaggle/input/music-test/music_test/S1m59_01.png
# /kaggle/input/music-test/music_test/S1m48_04.png
# /kaggle/input/music-test/music_test/S1m16_03.png
# /kaggle/input/music-test/music_test/S1m33_03.png
# /kaggle/input/music-test/music_test/S1m32_05.png
# /kaggle/input/music-test/music_test/S1m08_02.png
# /kaggle/input/music-test/music_test/S1m76_07.png
# /kaggle/input/music-test/music_test/S1m43_02.png
# /kaggle/input/music-test/music_test/S1m13_00.png
# /kaggle/input/music-test/music_test/S1m49_06.png
# /kaggle/input/music-test/music_test/S1m42_07.png
# /kaggle/input/music-test/music_test/S1m53_02.png
# /kaggle/input/music-test/music_test/S1m07_02.png
# /kaggle/input/music-test/music_test/S1m67_03.png
# /kaggle/input/music-test/music_test/S1m30_06.png
# /kaggle/input/music-test/music_test/S1m78_04.png
# /kaggle/input/music-test/music_test/S1m23_05.png
# /kaggle/input/music-test/music_test/S1m69_03.png
# /kaggle/input/music-test/music_test/S1m74_04.png
# /kaggle/input/music-test/music_test/S1m70_06.png
# /kaggle/input/music-test/music_test/S1m51_01.png
# /kaggle/input/music-test/music_test/S1m60_03.png
# /kaggle/input/music-test/music_test/S1m43_00.png
# /kaggle/input/music-test/music_test/S1m16_04.png
# /kaggle/input/music-test/music_test/S1m26_01.png
# /kaggle/input/music-test/music_test/S1m02_02.png
# /kaggle/input/music-test/music_test/S1m56_03.png
# /kaggle/input/music-test/music_test/S1m78_02.png
# /kaggle/input/music-test/music_test/S1m36_05.png
# /kaggle/input/music-test/music_test/S1m61_07.png
# /kaggle/input/music-test/music_test/S1m62_03.png
# /kaggle/input/music-test/music_test/S1m09_07.png
# /kaggle/input/music-test/music_test/S1m69_02.png
# /kaggle/input/music-test/music_test/S1m77_01.png
# /kaggle/input/music-test/music_test/S1m72_06.png
# /kaggle/input/music-test/music_test/S1m74_02.png
# /kaggle/input/music-test/music_test/S1m55_05.png
# /kaggle/input/music-test/music_test/S1m62_07.png
# /kaggle/input/music-test/music_test/S1m12_05.png
# /kaggle/input/music-test/music_test/S1m60_04.png
# /kaggle/input/music-test/music_test/S1m36_03.png
# /kaggle/input/music-test/music_test/S1m06_01.png
# /kaggle/input/music-test/music_test/S1m43_04.png
# /kaggle/input/music-test/music_test/S1m31_01.png
# /kaggle/input/music-test/music_test/S1m24_05.png
# /kaggle/input/music-test/music_test/S1m07_03.png
# /kaggle/input/music-test/music_test/S1m45_03.png
# /kaggle/input/music-test/music_test/S1m70_03.png
# /kaggle/input/music-test/music_test/S1m42_06.png
# /kaggle/input/music-test/music_test/S1m65_03.png
# /kaggle/input/music-test/music_test/S1m34_03.png
# /kaggle/input/music-test/music_test/S1m07_05.png
# /kaggle/input/music-test/music_test/S1m74_00.png
# /kaggle/input/music-test/music_test/S1m31_00.png
# /kaggle/input/music-test/music_test/S1m18_02.png
# /kaggle/input/music-test/music_test/S1m75_00.png
# /kaggle/input/music-test/music_test/S1m37_00.png
# /kaggle/input/music-test/music_test/S1m68_04.png
# /kaggle/input/music-test/music_test/S1m05_07.png
# /kaggle/input/music-test/music_test/S1m20_07.png
# /kaggle/input/music-test/music_test/S1m17_03.png
# /kaggle/input/music-test/music_test/S1m02_03.png
# /kaggle/input/music-test/music_test/S1m18_04.png
# /kaggle/input/music-test/music_test/S1m26_06.png
# /kaggle/input/music-test/music_test/S1m71_04.png
# /kaggle/input/music-test/music_test/S1m51_02.png
# /kaggle/input/music-test/music_test/S1m22_01.png
# /kaggle/input/music-test/music_test/S1m30_03.png
# /kaggle/input/music-test/music_test/S1m34_02.png
# /kaggle/input/music-test/music_test/S1m58_00.png
# /kaggle/input/music-test/music_test/S1m52_03.png
# /kaggle/input/music-test/music_test/S1m50_02.png
# /kaggle/input/music-test/music_test/S1m28_02.png
# /kaggle/input/music-test/music_test/S1m13_05.png
# /kaggle/input/music-test/music_test/S1m04_04.png
# /kaggle/input/music-test/music_test/S1m76_04.png
# /kaggle/input/music-test/music_test/S1m08_07.png
# /kaggle/input/music-test/music_test/S1m61_03.png
# /kaggle/input/music-test/music_test/S1m23_00.png
# /kaggle/input/music-test/music_test/S1m18_03.png
# /kaggle/input/music-test/music_test/S1m72_02.png
# /kaggle/input/music-test/music_test/S1m71_06.png
# /kaggle/input/music-test/music_test/S1m31_07.png
# /kaggle/input/music-test/music_test/S1m35_07.png
# /kaggle/input/music-test/music_test/S1m31_05.png
# /kaggle/input/music-test/music_test/S1m30_07.png
# /kaggle/input/music-test/music_test/S1m15_01.png
# /kaggle/input/music-test/music_test/S1m14_02.png
# /kaggle/input/music-test/music_test/S1m18_07.png
# /kaggle/input/music-test/music_test/S1m07_06.png
# /kaggle/input/music-test/music_test/S1m04_01.png
# /kaggle/input/music-test/music_test/S1m40_00.png
# /kaggle/input/music-test/music_test/S1m52_02.png
# /kaggle/input/music-test/music_test/S1m44_05.png
# /kaggle/input/music-test/music_test/S1m52_06.png
# /kaggle/input/music-test/music_test/S1m01_02.png
# /kaggle/input/music-test/music_test/S1m63_06.png
# /kaggle/input/music-test/music_test/S1m16_01.png
# /kaggle/input/music-test/music_test/S1m59_03.png
# /kaggle/input/music-test/music_test/S1m30_05.png
# /kaggle/input/music-test/music_test/S1m64_00.png
# /kaggle/input/music-test/music_test/S1m04_00.png
# /kaggle/input/music-test/music_test/S1m36_06.png
# /kaggle/input/music-test/music_test/S1m15_00.png
# /kaggle/input/music-test/music_test/S1m35_00.png
# /kaggle/input/music-test/music_test/S1m56_01.png
# /kaggle/input/music-test/music_test/S1m31_02.png
# /kaggle/input/music-test/music_test/S1m50_06.png
# /kaggle/input/music-test/music_test/S1m33_01.png
# /kaggle/input/music-test/music_test/S1m41_05.png
# /kaggle/input/music-train/music_train/S2m34_05.png
# /kaggle/input/music-train/music_train/S3m47_09.png
# /kaggle/input/music-train/music_train/S3m29_04.png
# /kaggle/input/music-train/music_train/S2m92_01.png
# /kaggle/input/music-train/music_train/S2m157_05.png
# /kaggle/input/music-train/music_train/S3m82_02.png
# /kaggle/input/music-train/music_train/S2m55_04.png
# /kaggle/input/music-train/music_train/S2m168_03.png
# /kaggle/input/music-train/music_train/S2m32_02.png
# /kaggle/input/music-train/music_train/S2m66_03.png
# /kaggle/input/music-train/music_train/S2m101_07.png
# /kaggle/input/music-train/music_train/S2m58_05.png
# /kaggle/input/music-train/music_train/S3m82_03.png
# /kaggle/input/music-train/music_train/S2m03_05.png
# /kaggle/input/music-train/music_train/S2m03_03.png
# /kaggle/input/music-train/music_train/S2m23_07.png
# /kaggle/input/music-train/music_train/S2m41_06.png
# /kaggle/input/music-train/music_train/S3m30_01.png
# /kaggle/input/music-train/music_train/S2m12_01.png
# /kaggle/input/music-train/music_train/S2m03_09.png
# /kaggle/input/music-train/music_train/S2m125_02.png
# /kaggle/input/music-train/music_train/S2m74_09.png
# /kaggle/input/music-train/music_train/S2m93_07.png
# /kaggle/input/music-train/music_train/S3m44_06.png
# /kaggle/input/music-train/music_train/S3m94_07.png
# /kaggle/input/music-train/music_train/S3m19_03.png
# /kaggle/input/music-train/music_train/S2m75_00.png
# /kaggle/input/music-train/music_train/S3m50_03.png
# /kaggle/input/music-train/music_train/S3m80_01.png
# /kaggle/input/music-train/music_train/S3m83_03.png
# /kaggle/input/music-train/music_train/S3m52_01.png
# /kaggle/input/music-train/music_train/S3m57_06.png
# /kaggle/input/music-train/music_train/S2m75_08.png
# /kaggle/input/music-train/music_train/S2m78_03.png
# /kaggle/input/music-train/music_train/S2m08_01.png
# /kaggle/input/music-train/music_train/S3m96_09.png
# /kaggle/input/music-train/music_train/S2m165_04.png
# /kaggle/input/music-train/music_train/S2m129_06.png
# /kaggle/input/music-train/music_train/S2m27_04.png
# /kaggle/input/music-train/music_train/S3m87_04.png
# /kaggle/input/music-train/music_train/S2m140_00.png
# /kaggle/input/music-train/music_train/S2m163_01.png
# /kaggle/input/music-train/music_train/S3m09_02.png
# /kaggle/input/music-train/music_train/S2m160_09.png
# /kaggle/input/music-train/music_train/S2m156_03.png
# /kaggle/input/music-train/music_train/S2m174_03.png
# /kaggle/input/music-train/music_train/S3m37_07.png
# /kaggle/input/music-train/music_train/S3m39_03.png
# /kaggle/input/music-train/music_train/S2m108_05.png
# /kaggle/input/music-train/music_train/S2m93_01.png
# /kaggle/input/music-train/music_train/S2m129_08.png
# /kaggle/input/music-train/music_train/S2m32_06.png
# /kaggle/input/music-train/music_train/S3m45_04.png
# /kaggle/input/music-train/music_train/S2m36_04.png
# /kaggle/input/music-train/music_train/S3m61_00.png
# /kaggle/input/music-train/music_train/S2m105_04.png
# /kaggle/input/music-train/music_train/S2m33_03.png
# /kaggle/input/music-train/music_train/S3m88_06.png
# /kaggle/input/music-train/music_train/S2m82_06.png
# /kaggle/input/music-train/music_train/S2m110_06.png
# /kaggle/input/music-train/music_train/S3m07_06.png
# /kaggle/input/music-train/music_train/S2m42_00.png
# /kaggle/input/music-train/music_train/S3m29_02.png
# /kaggle/input/music-train/music_train/S2m104_00.png
# /kaggle/input/music-train/music_train/S2m47_00.png
# /kaggle/input/music-train/music_train/S3m93_09.png
# /kaggle/input/music-train/music_train/S3m88_02.png
# /kaggle/input/music-train/music_train/S3m98_04.png
# /kaggle/input/music-train/music_train/S2m17_07.png
# /kaggle/input/music-train/music_train/S2m95_05.png
# /kaggle/input/music-train/music_train/S3m53_05.png
# /kaggle/input/music-train/music_train/S3m31_06.png
# /kaggle/input/music-train/music_train/S2m147_09.png
# /kaggle/input/music-train/music_train/S2m54_04.png
# /kaggle/input/music-train/music_train/S2m124_09.png
# /kaggle/input/music-train/music_train/S2m148_00.png
# /kaggle/input/music-train/music_train/S2m124_04.png
# /kaggle/input/music-train/music_train/S2m172_04.png
# /kaggle/input/music-train/music_train/S2m73_01.png
# /kaggle/input/music-train/music_train/S2m35_06.png
# /kaggle/input/music-train/music_train/S2m68_09.png
# /kaggle/input/music-train/music_train/S3m50_01.png
# /kaggle/input/music-train/music_train/S2m102_03.png
# /kaggle/input/music-train/music_train/S2m41_04.png
# /kaggle/input/music-train/music_train/S2m63_05.png
# /kaggle/input/music-train/music_train/S2m58_06.png
# /kaggle/input/music-train/music_train/S2m122_05.png
# /kaggle/input/music-train/music_train/S2m94_02.png
# /kaggle/input/music-train/music_train/S2m31_08.png
# /kaggle/input/music-train/music_train/S3m90_05.png
# /kaggle/input/music-train/music_train/S2m178_02.png
# /kaggle/input/music-train/music_train/S2m87_08.png
# /kaggle/input/music-train/music_train/S2m17_08.png
# /kaggle/input/music-train/music_train/S3m35_03.png
# /kaggle/input/music-train/music_train/S2m07_09.png
# /kaggle/input/music-train/music_train/S3m43_03.png
# /kaggle/input/music-train/music_train/S2m34_06.png
# /kaggle/input/music-train/music_train/S3m47_07.png
# /kaggle/input/music-train/music_train/S2m73_08.png
# /kaggle/input/music-train/music_train/S2m46_05.png
# /kaggle/input/music-train/music_train/S2m47_04.png
# /kaggle/input/music-train/music_train/S3m100_01.png
# /kaggle/input/music-train/music_train/S3m70_08.png
# /kaggle/input/music-train/music_train/S2m10_03.png
# /kaggle/input/music-train/music_train/S3m65_01.png
# /kaggle/input/music-train/music_train/S2m24_02.png
# /kaggle/input/music-train/music_train/S2m17_03.png
# /kaggle/input/music-train/music_train/S2m51_01.png
# /kaggle/input/music-train/music_train/S3m05_03.png
# /kaggle/input/music-train/music_train/S3m39_02.png
# /kaggle/input/music-train/music_train/S3m12_02.png
# /kaggle/input/music-train/music_train/S3m81_00.png
# /kaggle/input/music-train/music_train/S2m176_00.png
# /kaggle/input/music-train/music_train/S2m171_00.png
# /kaggle/input/music-train/music_train/S2m153_03.png
# /kaggle/input/music-train/music_train/S2m08_02.png
# /kaggle/input/music-train/music_train/S3m68_09.png
# /kaggle/input/music-train/music_train/S2m159_03.png
# /kaggle/input/music-train/music_train/S2m53_05.png
# /kaggle/input/music-train/music_train/S3m70_03.png
# /kaggle/input/music-train/music_train/S2m07_04.png
# /kaggle/input/music-train/music_train/S2m149_05.png
# /kaggle/input/music-train/music_train/S2m43_09.png
# /kaggle/input/music-train/music_train/S2m64_07.png
# /kaggle/input/music-train/music_train/S2m138_00.png
# /kaggle/input/music-train/music_train/S2m161_03.png
# /kaggle/input/music-train/music_train/S2m34_07.png
# /kaggle/input/music-train/music_train/S2m148_03.png
# /kaggle/input/music-train/music_train/S2m148_04.png
# /kaggle/input/music-train/music_train/S3m19_05.png
# /kaggle/input/music-train/music_train/S2m184_03.png
# /kaggle/input/music-train/music_train/S3m59_09.png
# /kaggle/input/music-train/music_train/S2m45_07.png
# /kaggle/input/music-train/music_train/S2m123_05.png
# /kaggle/input/music-train/music_train/S3m31_09.png
# /kaggle/input/music-train/music_train/S3m82_06.png
# /kaggle/input/music-train/music_train/S2m48_01.png
# /kaggle/input/music-train/music_train/S2m09_08.png
# /kaggle/input/music-train/music_train/S2m79_08.png
# /kaggle/input/music-train/music_train/S3m85_09.png
# /kaggle/input/music-train/music_train/S3m95_00.png
# /kaggle/input/music-train/music_train/S2m69_02.png
# /kaggle/input/music-train/music_train/S3m28_08.png
# /kaggle/input/music-train/music_train/S2m36_03.png
# /kaggle/input/music-train/music_train/S2m167_00.png
# /kaggle/input/music-train/music_train/S3m83_05.png
# /kaggle/input/music-train/music_train/S2m58_09.png
# /kaggle/input/music-train/music_train/S2m179_03.png
# /kaggle/input/music-train/music_train/S2m35_08.png
# /kaggle/input/music-train/music_train/S2m48_05.png
# /kaggle/input/music-train/music_train/S3m70_06.png
# /kaggle/input/music-train/music_train/S2m55_00.png
# /kaggle/input/music-train/music_train/S3m74_04.png
# /kaggle/input/music-train/music_train/S2m68_08.png
# /kaggle/input/music-train/music_train/S3m76_04.png
# /kaggle/input/music-train/music_train/S3m97_04.png
# /kaggle/input/music-train/music_train/S2m84_09.png
# /kaggle/input/music-train/music_train/S3m49_02.png
# /kaggle/input/music-train/music_train/S3m55_01.png
# /kaggle/input/music-train/music_train/S3m03_00.png
# /kaggle/input/music-train/music_train/S2m171_01.png
# /kaggle/input/music-train/music_train/S2m118_06.png
# /kaggle/input/music-train/music_train/S2m65_08.png
# /kaggle/input/music-train/music_train/S3m70_05.png
# /kaggle/input/music-train/music_train/S2m72_04.png
# /kaggle/input/music-train/music_train/S2m130_01.png
# /kaggle/input/music-train/music_train/S2m32_01.png
# /kaggle/input/music-train/music_train/S2m166_02.png
# /kaggle/input/music-train/music_train/S2m155_02.png
# /kaggle/input/music-train/music_train/S2m03_01.png
# /kaggle/input/music-train/music_train/S2m42_01.png
# /kaggle/input/music-train/music_train/S3m05_07.png
# /kaggle/input/music-train/music_train/S3m43_00.png
# /kaggle/input/music-train/music_train/S2m152_06.png
# /kaggle/input/music-train/music_train/S3m33_00.png
# /kaggle/input/music-train/music_train/S3m77_04.png
# /kaggle/input/music-train/music_train/S2m107_04.png
# /kaggle/input/music-train/music_train/S3m16_02.png
# /kaggle/input/music-train/music_train/S3m12_08.png
# /kaggle/input/music-train/music_train/S2m37_09.png
# /kaggle/input/music-train/music_train/S2m111_04.png
# /kaggle/input/music-train/music_train/S2m60_04.png
# /kaggle/input/music-train/music_train/S2m121_09.png
# /kaggle/input/music-train/music_train/S3m87_01.png
# /kaggle/input/music-train/music_train/S2m166_04.png
# /kaggle/input/music-train/music_train/S2m36_08.png
# /kaggle/input/music-train/music_train/S3m97_08.png
# /kaggle/input/music-train/music_train/S2m11_03.png
# /kaggle/input/music-train/music_train/S2m110_03.png
# /kaggle/input/music-train/music_train/S2m108_06.png
# /kaggle/input/music-train/music_train/S2m08_09.png
# /kaggle/input/music-train/music_train/S2m167_05.png
# /kaggle/input/music-train/music_train/S2m86_01.png
# /kaggle/input/music-train/music_train/S2m147_01.png
# /kaggle/input/music-train/music_train/S2m113_08.png
# /kaggle/input/music-train/music_train/S2m18_05.png
# /kaggle/input/music-train/music_train/S2m156_04.png
# /kaggle/input/music-train/music_train/S2m125_00.png
# /kaggle/input/music-train/music_train/S3m49_01.png
# /kaggle/input/music-train/music_train/S3m37_02.png
# /kaggle/input/music-train/music_train/S2m81_04.png
# /kaggle/input/music-train/music_train/S2m125_01.png
# /kaggle/input/music-train/music_train/S2m01_08.png
# /kaggle/input/music-train/music_train/S2m180_08.png
# /kaggle/input/music-train/music_train/S2m95_09.png
# /kaggle/input/music-train/music_train/S3m03_01.png
# /kaggle/input/music-train/music_train/S2m137_05.png
# /kaggle/input/music-train/music_train/S3m86_07.png
# /kaggle/input/music-train/music_train/S2m104_05.png
# /kaggle/input/music-train/music_train/S2m68_00.png
# /kaggle/input/music-train/music_train/S3m54_06.png
# /kaggle/input/music-train/music_train/S3m80_06.png
# /kaggle/input/music-train/music_train/S3m62_06.png
# /kaggle/input/music-train/music_train/S2m35_09.png
# /kaggle/input/music-train/music_train/S2m73_00.png
# /kaggle/input/music-train/music_train/S2m77_06.png
# /kaggle/input/music-train/music_train/S2m92_06.png
# /kaggle/input/music-train/music_train/S3m70_00.png
# /kaggle/input/music-train/music_train/S2m65_01.png
# /kaggle/input/music-train/music_train/S2m150_08.png
# /kaggle/input/music-train/music_train/S2m89_08.png
# /kaggle/input/music-train/music_train/S2m85_01.png
# /kaggle/input/music-train/music_train/S3m50_02.png
# /kaggle/input/music-train/music_train/S2m177_05.png
# /kaggle/input/music-train/music_train/S2m66_00.png
# /kaggle/input/music-train/music_train/S2m107_05.png
# /kaggle/input/music-train/music_train/S2m155_01.png
# /kaggle/input/music-train/music_train/S2m154_02.png
# /kaggle/input/music-train/music_train/S3m46_09.png
# /kaggle/input/music-train/music_train/S2m63_06.png
# /kaggle/input/music-train/music_train/S3m22_08.png
# /kaggle/input/music-train/music_train/S2m90_03.png
# /kaggle/input/music-train/music_train/S3m11_04.png
# /kaggle/input/music-train/music_train/S2m03_02.png
# /kaggle/input/music-train/music_train/S2m182_06.png
# /kaggle/input/music-train/music_train/S3m65_09.png
# /kaggle/input/music-train/music_train/S3m61_03.png
# /kaggle/input/music-train/music_train/S2m157_01.png
# /kaggle/input/music-train/music_train/S2m120_01.png
# /kaggle/input/music-train/music_train/S3m23_00.png
# /kaggle/input/music-train/music_train/S2m06_05.png
# /kaggle/input/music-train/music_train/S2m117_02.png
# /kaggle/input/music-train/music_train/S3m32_00.png
# /kaggle/input/music-train/music_train/S3m37_06.png
# /kaggle/input/music-train/music_train/S2m05_01.png
# /kaggle/input/music-train/music_train/S2m61_03.png
# /kaggle/input/music-train/music_train/S3m15_07.png
# /kaggle/input/music-train/music_train/S2m181_06.png
# /kaggle/input/music-train/music_train/S3m59_07.png
# /kaggle/input/music-train/music_train/S2m52_04.png
# /kaggle/input/music-train/music_train/S2m68_07.png
# /kaggle/input/music-train/music_train/S2m158_07.png
# /kaggle/input/music-train/music_train/S3m61_09.png
# /kaggle/input/music-train/music_train/S2m83_09.png
# /kaggle/input/music-train/music_train/S3m65_00.png
# /kaggle/input/music-train/music_train/S2m106_07.png
# /kaggle/input/music-train/music_train/S2m105_00.png
# /kaggle/input/music-train/music_train/S2m173_02.png
# /kaggle/input/music-train/music_train/S2m82_02.png
# /kaggle/input/music-train/music_train/S2m142_00.png
# /kaggle/input/music-train/music_train/S2m52_02.png
# /kaggle/input/music-train/music_train/S2m38_04.png
# /kaggle/input/music-train/music_train/S3m40_02.png
# /kaggle/input/music-train/music_train/S2m87_07.png
# /kaggle/input/music-train/music_train/S2m98_09.png
# /kaggle/input/music-train/music_train/S2m29_09.png
# /kaggle/input/music-train/music_train/S3m62_07.png
# /kaggle/input/music-train/music_train/S2m22_02.png
# /kaggle/input/music-train/music_train/S2m84_07.png
# /kaggle/input/music-train/music_train/S2m116_09.png
# /kaggle/input/music-train/music_train/S2m49_02.png
# /kaggle/input/music-train/music_train/S2m24_00.png
# /kaggle/input/music-train/music_train/S2m124_05.png
# /kaggle/input/music-train/music_train/S3m64_06.png
# /kaggle/input/music-train/music_train/S2m127_08.png
# /kaggle/input/music-train/music_train/S2m132_07.png
# /kaggle/input/music-train/music_train/S3m97_03.png
# /kaggle/input/music-train/music_train/S2m83_05.png
# /kaggle/input/music-train/music_train/S2m172_07.png
# /kaggle/input/music-train/music_train/S2m127_05.png
# /kaggle/input/music-train/music_train/S2m46_03.png
# /kaggle/input/music-train/music_train/S2m175_06.png
# /kaggle/input/music-train/music_train/S2m98_01.png
# /kaggle/input/music-train/music_train/S2m179_07.png
# /kaggle/input/music-train/music_train/S3m84_06.png
# /kaggle/input/music-train/music_train/S3m17_06.png
# /kaggle/input/music-train/music_train/S2m40_09.png
# /kaggle/input/music-train/music_train/S2m146_02.png
# /kaggle/input/music-train/music_train/S2m163_04.png
# /kaggle/input/music-train/music_train/S3m13_04.png
# /kaggle/input/music-train/music_train/S2m75_02.png
# /kaggle/input/music-train/music_train/S3m28_02.png
# /kaggle/input/music-train/music_train/S2m96_02.png
# /kaggle/input/music-train/music_train/S2m136_09.png
# /kaggle/input/music-train/music_train/S2m174_02.png
# /kaggle/input/music-train/music_train/S3m15_01.png
# /kaggle/input/music-train/music_train/S2m01_06.png
# /kaggle/input/music-train/music_train/S3m42_02.png
# /kaggle/input/music-train/music_train/S3m04_00.png
# /kaggle/input/music-train/music_train/S2m130_02.png
# /kaggle/input/music-train/music_train/S2m175_04.png
# /kaggle/input/music-train/music_train/S2m55_02.png
# /kaggle/input/music-train/music_train/S3m56_03.png
# /kaggle/input/music-train/music_train/S3m61_07.png
# /kaggle/input/music-train/music_train/S3m58_00.png
# /kaggle/input/music-train/music_train/S3m92_08.png
# /kaggle/input/music-train/music_train/S2m87_04.png
# /kaggle/input/music-train/music_train/S2m08_00.png
# /kaggle/input/music-train/music_train/S2m96_04.png
# /kaggle/input/music-train/music_train/S2m75_06.png
# /kaggle/input/music-train/music_train/S2m143_05.png
# /kaggle/input/music-train/music_train/S3m77_02.png
# /kaggle/input/music-train/music_train/S3m41_01.png
# /kaggle/input/music-train/music_train/S2m46_09.png
# /kaggle/input/music-train/music_train/S3m85_07.png
# /kaggle/input/music-train/music_train/S2m162_07.png
# /kaggle/input/music-train/music_train/S3m89_00.png
# /kaggle/input/music-train/music_train/S2m66_08.png
# /kaggle/input/music-train/music_train/S2m141_05.png
# /kaggle/input/music-train/music_train/S2m89_05.png
# /kaggle/input/music-train/music_train/S3m76_09.png
# /kaggle/input/music-train/music_train/S2m87_01.png
# /kaggle/input/music-train/music_train/S2m81_03.png
# /kaggle/input/music-train/music_train/S2m37_05.png
# /kaggle/input/music-train/music_train/S2m49_07.png
# /kaggle/input/music-train/music_train/S3m56_04.png
# /kaggle/input/music-train/music_train/S2m110_04.png
# /kaggle/input/music-train/music_train/S2m78_04.png
# /kaggle/input/music-train/music_train/S2m07_07.png
# /kaggle/input/music-train/music_train/S2m25_05.png
# /kaggle/input/music-train/music_train/S2m16_03.png
# /kaggle/input/music-train/music_train/S2m16_09.png
# ...
# /kaggle/input/music-train/music_train/S2m58_00.png
# /kaggle/input/music-train/music_train/S3m67_01.png
# /kaggle/input/music-train/music_train/S2m137_01.png
# /kaggle/input/music-train/music_train/S3m76_06.png
# /kaggle/input/music-train/music_train/S3m19_08.png
# /kaggle/input/music-train/music_train/S2m99_06.png
# /kaggle/input/music-train/music_train/S2m162_05.png
# /kaggle/input/music-train/music_train/S2m26_02.png
# /kaggle/input/music-train/music_train/S2m165_05.png
# /kaggle/input/music-train/music_train/S2m150_06.png
# /kaggle/input/music-train/music_train/S2m109_04.png
# /kaggle/input/music-train/music_train/S2m90_01.png
# /kaggle/input/music-train/music_train/S2m57_09.png
# /kaggle/input/music-train/music_train/S3m89_04.png
# /kaggle/input/music-train/music_train/S3m26_05.png
# /kaggle/input/music-train/music_train/S2m168_00.png
# /kaggle/input/music-train/music_train/S2m18_08.png
# /kaggle/input/music-train/music_train/S2m122_01.png
# /kaggle/input/music-train/music_train/S2m05_04.png
# /kaggle/input/music-train/music_train/S2m182_05.png
# /kaggle/input/music-train/music_train/S2m159_01.png
# /kaggle/input/music-train/music_train/S2m37_01.png
# /kaggle/input/music-train/music_train/S2m25_07.png
# /kaggle/input/music-train/music_train/S2m09_06.png
# /kaggle/input/music-train/music_train/S3m34_03.png
# /kaggle/input/music-train/music_train/S3m55_06.png
# /kaggle/input/music-train/music_train/S3m29_06.png
# /kaggle/input/music-train/music_train/S2m161_01.png
# /kaggle/input/music-train/music_train/S2m56_04.png
# /kaggle/input/music-train/music_train/S3m37_05.png
# /kaggle/input/music-train/music_train/S3m72_06.png
# /kaggle/input/music-train/music_train/S2m40_08.png
# /kaggle/input/music-train/music_train/S3m05_08.png
# /kaggle/input/music-train/music_train/S2m31_05.png
# /kaggle/input/music-train/music_train/S2m47_03.png
# /kaggle/input/music-train/music_train/S3m66_04.png
# /kaggle/input/music-train/music_train/S2m09_04.png
# /kaggle/input/music-train/music_train/S3m89_09.png
# /kaggle/input/music-train/music_train/S2m44_08.png
# /kaggle/input/music-train/music_train/S2m73_04.png
# /kaggle/input/music-train/music_train/S3m46_06.png
# /kaggle/input/music-train/music_train/S2m174_04.png
# /kaggle/input/music-train/music_train/S2m184_00.png
# /kaggle/input/music-train/music_train/S3m100_09.png
# /kaggle/input/music-train/music_train/S3m19_07.png
# /kaggle/input/music-train/music_train/S2m154_00.png
# /kaggle/input/music-train/music_train/S3m32_05.png
# /kaggle/input/music-train/music_train/S3m64_09.png
# /kaggle/input/music-train/music_train/S2m77_04.png
# /kaggle/input/music-train/music_train/S3m69_08.png
# /kaggle/input/music-train/music_train/S2m154_08.png
# /kaggle/input/music-train/music_train/S3m82_05.png
# /kaggle/input/music-train/music_train/S3m27_09.png
# /kaggle/input/music-train/music_train/S2m161_05.png
# /kaggle/input/music-train/music_train/S2m105_01.png
# /kaggle/input/music-train/music_train/S2m76_09.png
# /kaggle/input/music-train/music_train/S2m10_07.png
# /kaggle/input/music-train/music_train/S3m20_00.png
# /kaggle/input/music-train/music_train/S3m87_06.png
# /kaggle/input/music-train/music_train/S3m95_09.png
# /kaggle/input/music-train/music_train/S2m148_09.png
# /kaggle/input/music-train/music_train/S2m116_08.png
# /kaggle/input/music-train/music_train/S2m156_06.png
# /kaggle/input/music-train/music_train/S2m51_04.png
# /kaggle/input/music-train/music_train/S3m70_01.png
# /kaggle/input/music-train/music_train/S2m40_03.png
# /kaggle/input/music-train/music_train/S2m47_09.png
# /kaggle/input/music-train/music_train/S3m65_03.png
# /kaggle/input/music-train/music_train/S2m185_05.png
# /kaggle/input/music-train/music_train/S2m07_03.png
# /kaggle/input/music-train/music_train/S2m59_02.png
# /kaggle/input/music-train/music_train/S2m72_03.png
# /kaggle/input/music-train/music_train/S2m51_06.png
# /kaggle/input/music-train/music_train/S3m99_03.png
# /kaggle/input/music-train/music_train/S2m112_00.png
# /kaggle/input/music-train/music_train/S3m58_07.png
# /kaggle/input/music-train/music_train/S2m112_07.png
# /kaggle/input/music-train/music_train/S2m25_02.png
# /kaggle/input/music-train/music_train/S3m57_05.png
# /kaggle/input/music-train/music_train/S2m179_00.png
# /kaggle/input/music-train/music_train/S2m121_08.png
# /kaggle/input/music-train/music_train/S3m66_06.png
# /kaggle/input/music-train/music_train/S3m36_09.png
# /kaggle/input/music-train/music_train/S2m40_07.png
# /kaggle/input/music-train/music_train/S2m126_04.png
# /kaggle/input/music-train/music_train/S2m89_09.png
# /kaggle/input/music-train/music_train/S2m46_08.png
# /kaggle/input/music-train/music_train/S2m56_05.png
# /kaggle/input/music-train/music_train/S2m34_09.png
# /kaggle/input/music-train/music_train/S2m28_03.png
# /kaggle/input/music-train/music_train/S2m63_02.png
# /kaggle/input/music-train/music_train/S3m17_01.png
# /kaggle/input/music-train/music_train/S3m12_09.png
# /kaggle/input/music-train/music_train/S2m04_08.png
# /kaggle/input/music-train/music_train/S2m17_06.png
# /kaggle/input/music-train/music_train/S2m74_03.png
# /kaggle/input/music-train/music_train/S2m152_00.png
# /kaggle/input/music-train/music_train/S2m146_00.png
# /kaggle/input/music-train/music_train/S2m73_07.png
# /kaggle/input/music-train/music_train/S3m98_05.png
# /kaggle/input/music-train/music_train/S2m85_02.png
# /kaggle/input/music-train/music_train/S2m56_01.png
# /kaggle/input/music-train/music_train/S2m164_00.png
# /kaggle/input/music-train/music_train/S2m179_01.png
# /kaggle/input/music-train/music_train/S3m37_00.png
# /kaggle/input/music-train/music_train/S3m33_04.png
# /kaggle/input/music-train/music_train/S2m107_03.png
# /kaggle/input/music-train/music_train/S3m98_03.png
# /kaggle/input/music-train/music_train/S3m57_00.png
# /kaggle/input/music-train/music_train/S2m39_07.png
# /kaggle/input/music-train/music_train/S2m122_04.png
# /kaggle/input/music-train/music_train/S2m141_01.png
# /kaggle/input/music-train/music_train/S3m10_02.png
# /kaggle/input/music-train/music_train/S2m39_06.png
# /kaggle/input/music-train/music_train/S3m03_08.png
# /kaggle/input/music-train/music_train/S2m118_03.png
# /kaggle/input/music-train/music_train/S2m151_04.png
# /kaggle/input/music-train/music_train/S2m182_01.png
# /kaggle/input/music-train/music_train/S2m48_04.png
# /kaggle/input/music-train/music_train/S2m145_05.png
# /kaggle/input/music-train/music_train/S2m104_02.png
# /kaggle/input/music-train/music_train/S2m39_08.png
# /kaggle/input/music-train/music_train/S2m109_01.png
# /kaggle/input/music-train/music_train/S3m90_01.png
# /kaggle/input/music-train/music_train/S2m21_04.png
# /kaggle/input/music-train/music_train/S2m81_06.png
# /kaggle/input/music-train/music_train/S2m61_06.png
# /kaggle/input/music-train/music_train/S2m40_01.png
# /kaggle/input/music-train/music_train/S3m28_06.png
# /kaggle/input/music-train/music_train/S2m62_04.png
# /kaggle/input/music-train/music_train/S2m111_07.png
# /kaggle/input/music-train/music_train/S2m80_04.png
# /kaggle/input/music-train/music_train/S2m126_03.png
# /kaggle/input/music-train/music_train/S2m90_07.png
# /kaggle/input/music-train/music_train/S2m57_00.png
# /kaggle/input/music-train/music_train/S2m147_02.png
# /kaggle/input/music-train/music_train/S2m86_02.png
# /kaggle/input/music-train/music_train/S2m72_08.png
# /kaggle/input/music-train/music_train/S3m25_08.png
# /kaggle/input/music-train/music_train/S2m08_06.png
# /kaggle/input/music-train/music_train/S2m71_02.png
# /kaggle/input/music-train/music_train/S2m147_05.png
# /kaggle/input/music-train/music_train/S2m14_07.png
# /kaggle/input/music-train/music_train/S2m176_01.png
# /kaggle/input/music-train/music_train/S2m154_03.png
# /kaggle/input/music-train/music_train/S2m97_02.png
# /kaggle/input/music-train/music_train/S3m66_05.png
# /kaggle/input/music-train/music_train/S2m111_09.png
# /kaggle/input/music-train/music_train/S2m104_04.png
# /kaggle/input/music-train/music_train/S2m101_01.png
# /kaggle/input/music-train/music_train/S3m91_08.png
# /kaggle/input/music-train/music_train/S2m42_07.png
# /kaggle/input/music-train/music_train/S2m75_01.png
# /kaggle/input/music-train/music_train/S3m40_09.png
# /kaggle/input/music-train/music_train/S3m82_09.png
# /kaggle/input/music-train/music_train/S3m07_05.png
# /kaggle/input/music-train/music_train/S3m14_08.png
# /kaggle/input/music-train/music_train/S2m47_08.png
# /kaggle/input/music-train/music_train/S2m136_02.png
# /kaggle/input/music-train/music_train/S3m49_08.png
# /kaggle/input/music-train/music_train/S2m160_01.png
# /kaggle/input/music-train/music_train/S2m23_02.png
# /kaggle/input/music-train/music_train/S3m81_02.png
# /kaggle/input/music-train/music_train/S2m80_01.png
# /kaggle/input/music-train/music_train/S3m76_02.png
# /kaggle/input/music-train/music_train/S3m84_07.png
# /kaggle/input/music-train/music_train/S2m101_03.png
# /kaggle/input/music-train/music_train/S2m15_03.png
# /kaggle/input/music-train/music_train/S2m06_06.png
# /kaggle/input/music-train/music_train/S2m62_01.png
# /kaggle/input/music-train/music_train/S2m158_05.png
# /kaggle/input/music-train/music_train/S2m01_05.png
# /kaggle/input/music-train/music_train/S2m114_03.png
# /kaggle/input/music-train/music_train/S2m28_05.png
# /kaggle/input/music-train/music_train/S2m145_00.png
# /kaggle/input/music-train/music_train/S2m79_03.png
# /kaggle/input/music-train/music_train/S2m132_04.png
# /kaggle/input/music-train/music_train/S2m53_01.png
# /kaggle/input/music-train/music_train/S3m68_07.png
# /kaggle/input/music-train/music_train/S2m39_09.png
# /kaggle/input/music-train/music_train/S3m44_05.png
# /kaggle/input/music-train/music_train/S3m96_06.png
# /kaggle/input/music-train/music_train/S2m113_07.png
# /kaggle/input/music-train/music_train/S2m170_08.png
# /kaggle/input/music-train/music_train/S3m88_07.png
# /kaggle/input/music-train/music_train/S2m69_05.png
# /kaggle/input/music-train/music_train/S2m56_07.png
# /kaggle/input/music-train/music_train/S2m74_00.png
# /kaggle/input/music-train/music_train/S2m106_05.png
# /kaggle/input/music-train/music_train/S2m60_06.png
# /kaggle/input/music-train/music_train/S3m73_03.png
# /kaggle/input/music-train/music_train/S2m141_08.png
# /kaggle/input/music-train/music_train/S2m27_08.png
# /kaggle/input/music-train/music_train/S3m22_05.png
# /kaggle/input/music-train/music_train/S2m18_01.png
# /kaggle/input/music-train/music_train/S2m12_02.png
# /kaggle/input/music-train/music_train/S2m84_01.png
# /kaggle/input/music-train/music_train/S2m35_05.png
# /kaggle/input/music-train/music_train/S2m170_00.png
# /kaggle/input/music-train/music_train/S3m95_05.png
# /kaggle/input/music-train/music_train/S2m21_06.png
# /kaggle/input/music-train/music_train/S2m185_02.png
# /kaggle/input/music-train/music_train/S2m98_02.png
# /kaggle/input/music-train/music_train/S2m59_09.png
# /kaggle/input/music-train/music_train/S3m57_09.png
# /kaggle/input/music-train/music_train/S2m44_09.png
# /kaggle/input/music-train/music_train/S3m48_00.png
# /kaggle/input/music-train/music_train/S2m84_08.png
# /kaggle/input/music-train/music_train/S3m62_03.png
# /kaggle/input/music-train/music_train/S2m144_07.png
# /kaggle/input/music-train/music_train/S2m48_07.png
# /kaggle/input/music-train/music_train/S2m28_07.png
# /kaggle/input/music-train/music_train/S3m49_07.png
# /kaggle/input/music-train/music_train/S3m53_00.png
# /kaggle/input/music-train/music_train/S2m182_04.png
# /kaggle/input/music-train/music_train/S3m82_01.png
# /kaggle/input/music-train/music_train/S3m78_03.png
# /kaggle/input/music-train/music_train/S2m14_03.png
# /kaggle/input/music-train/music_train/S2m141_03.png
# /kaggle/input/music-train/music_train/S3m69_01.png
# /kaggle/input/music-train/music_train/S2m117_07.png
# /kaggle/input/music-train/music_train/S2m04_06.png
# /kaggle/input/music-train/music_train/S2m140_05.png
# /kaggle/input/music-train/music_train/S3m95_01.png
# /kaggle/input/music-train/music_train/S2m73_05.png
# /kaggle/input/music-train/music_train/S2m105_06.png
# /kaggle/input/music-train/music_train/S2m163_02.png
# /kaggle/input/music-train/music_train/S3m35_06.png
# /kaggle/input/music-train/music_train/S3m32_01.png
# /kaggle/input/music-train/music_train/S2m75_04.png
# /kaggle/input/music-train/music_train/S2m26_04.png
# /kaggle/input/music-train/music_train/S3m100_00.png
# /kaggle/input/music-train/music_train/S2m59_00.png
# /kaggle/input/music-train/music_train/S2m93_04.png
# /kaggle/input/music-train/music_train/S2m24_03.png
# /kaggle/input/music-train/music_train/S2m169_00.png
# /kaggle/input/music-train/music_train/S3m03_03.png
# /kaggle/input/music-train/music_train/S2m48_06.png
# /kaggle/input/music-train/music_train/S3m08_08.png
# /kaggle/input/music-train/music_train/S2m101_02.png
# /kaggle/input/music-train/music_train/S2m165_07.png
# /kaggle/input/music-train/music_train/S3m28_03.png
# /kaggle/input/music-train/music_train/S2m09_03.png
# /kaggle/input/music-train/music_train/S3m08_05.png
# /kaggle/input/music-train/music_train/S2m153_07.png
# /kaggle/input/music-train/music_train/S3m34_09.png
# /kaggle/input/music-train/music_train/S2m71_03.png
# /kaggle/input/music-train/music_train/S2m91_00.png
# /kaggle/input/music-train/music_train/S3m57_07.png
# /kaggle/input/music-train/music_train/S3m82_04.png
# /kaggle/input/music-train/music_train/S3m65_07.png
# /kaggle/input/music-train/music_train/S3m05_02.png
# /kaggle/input/music-train/music_train/S3m51_06.png
# /kaggle/input/music-train/music_train/S3m63_05.png
# /kaggle/input/music-train/music_train/S3m87_05.png
# /kaggle/input/music-train/music_train/S3m54_07.png
# /kaggle/input/music-train/music_train/S2m134_08.png
# /kaggle/input/music-train/music_train/S2m135_09.png
# /kaggle/input/music-train/music_train/S3m25_00.png
# /kaggle/input/music-train/music_train/S2m09_09.png
# /kaggle/input/music-train/music_train/S2m14_09.png
# /kaggle/input/music-train/music_train/S3m75_02.png
# /kaggle/input/music-train/music_train/S2m76_01.png
# /kaggle/input/music-train/music_train/S2m128_07.png
# /kaggle/input/music-train/music_train/S3m51_05.png
# /kaggle/input/music-train/music_train/S2m12_00.png
# /kaggle/input/music-train/music_train/S2m135_05.png
# /kaggle/input/music-train/music_train/S2m85_00.png
# /kaggle/input/music-train/music_train/S3m16_03.png
# /kaggle/input/music-train/music_train/S2m82_07.png
# /kaggle/input/music-train/music_train/S2m103_04.png
# /kaggle/input/music-train/music_train/S2m72_05.png
# /kaggle/input/music-train/music_train/S2m39_02.png
# /kaggle/input/music-train/music_train/S3m04_07.png
# /kaggle/input/music-train/music_train/S3m92_00.png
# /kaggle/input/music-train/music_train/S2m76_02.png
# /kaggle/input/music-train/music_train/S2m12_08.png
# /kaggle/input/music-train/music_train/S2m129_05.png
# /kaggle/input/music-train/music_train/S2m54_07.png
# /kaggle/input/music-train/music_train/S2m02_06.png
# /kaggle/input/music-train/music_train/S2m149_02.png
# /kaggle/input/music-train/music_train/S3m61_08.png
# /kaggle/input/music-train/music_train/S3m13_03.png
# /kaggle/input/music-train/music_train/S2m182_02.png
# /kaggle/input/music-train/music_train/S2m35_03.png
# /kaggle/input/music-train/music_train/S2m129_03.png
# /kaggle/input/music-train/music_train/S3m86_03.png
# /kaggle/input/music-train/music_train/S2m62_05.png
# /kaggle/input/music-train/music_train/S2m72_09.png
# /kaggle/input/music-train/music_train/S3m02_06.png
# /kaggle/input/music-train/music_train/S2m160_08.png
# /kaggle/input/music-train/music_train/S2m126_01.png
# /kaggle/input/music-train/music_train/S2m132_05.png
# /kaggle/input/music-train/music_train/S2m154_04.png
# /kaggle/input/music-train/music_train/S3m40_07.png
# /kaggle/input/music-train/music_train/S2m164_08.png
# /kaggle/input/music-train/music_train/S2m179_06.png
# /kaggle/input/music-train/music_train/S2m120_04.png
# /kaggle/input/music-train/music_train/S2m168_04.png
# /kaggle/input/music-train/music_train/S2m145_01.png
# /kaggle/input/music-train/music_train/S2m106_06.png
# /kaggle/input/music-train/music_train/S2m147_08.png
# /kaggle/input/music-train/music_train/S3m74_06.png
# /kaggle/input/music-train/music_train/S2m88_05.png
# /kaggle/input/music-train/music_train/S3m48_06.png
# /kaggle/input/music-train/music_train/S3m18_05.png
# /kaggle/input/music-train/music_train/S2m74_07.png
# /kaggle/input/music-train/music_train/S2m88_09.png
# /kaggle/input/music-train/music_train/S2m05_05.png
# /kaggle/input/music-scale-recognition-by-cnn/train_truth.csv
# /kaggle/input/music-scale-recognition-by-cnn/sample_truth.csv

# %%
import torch
import torch.nn as nn
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
import os

# --- 1. Dataset Configuration ---
class MusicScaleDataset(Dataset):
    """
    Custom Dataset class for loading music spectrogram images and their corresponding labels.
    """
    def __init__(self, csv_file, img_dir, transform=None):
        # Load the ground truth CSV containing filenames and category labels
        self.data_frame = pd.read_csv(csv_file)
        # Root directory for image files
        self.img_dir = img_dir
        # Image transformations to be applied
        self.transform = transform

    def __len__(self):
        # Return the total number of samples in the dataset
        return len(self.data_frame)

    def __getitem__(self, idx):
        # Construct the full image path using the filename from the CSV
        img_name = os.path.join(self.img_dir, self.data_frame.iloc[idx, 0])
        # Open the image and ensure it is in RGB format
        image = Image.open(img_name).convert('RGB')
        
        # Extract the integer label representing the musical note (0-87)
        label = int(self.data_frame.iloc[idx, 1])
        
        # Apply transformations if provided
        if self.transform:
            image = self.transform(image)
            
        return image, label

# %%
# --- 2. Image Preprocessing ---
# Define the transformation pipeline for the ResNet model
transform = transforms.Compose([
    transforms.Resize((224, 224)),      # Standard size for ResNet input
    transforms.ToTensor(),              # Convert PIL Image to PyTorch Tensor
    transforms.Normalize(               # Normalize using ImageNet statistics
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

# Initialize the training dataset with Kaggle input paths
train_dataset = MusicScaleDataset(
    csv_file='/kaggle/input/music-scale-recognition-by-cnn/train_truth.csv', 
    img_dir='/kaggle/input/music-train/music_train',
    transform=transform
)

# Initialize DataLoader for batch processing
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
# --- 3. Model Definition (Transfer Learning) ---
from torchvision.models import ResNet18_Weights

# Load pre-trained ResNet-18 weights to utilize established feature extractors
model = models.resnet18(weights=ResNet18_Weights.DEFAULT)

# Modify the final Fully Connected layer to output 88 classes (piano notes)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 88)

# Detect if GPU is available and move the model to the target device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print("Device detected:", device)
# Out:
# Device detected: cpu

# %%
# --- 4. Training Parameters ---
import torch.optim as optim
# Loss function for multi-class classification
criterion = nn.CrossEntropyLoss()
# Adam optimizer with a learning rate of 0.0001 for stable convergence
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# --- 5. Training Loop ---
import torch.optim as optim

def train(epochs):
    model.train() # Set the model to training mode
    for epoch in range(epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            # Transfer data to GPU/CPU
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()           # Reset gradients from the previous step
            outputs = model(images)         # Forward pass
            loss = criterion(outputs, labels) # Calculate loss
            loss.backward()                 # Backward pass (backpropagation)
            optimizer.step()                # Update weights
            
            running_loss += loss.item()
        
        # Log average loss per epoch
        print(f"Epoch {epoch+1}, Average Loss: {running_loss/len(train_loader):.4f}")

# %%
# --- 6. Inference and Submission Generation ---
def predict_and_save(test_img_dir, sample_csv):
    model.eval() # Set the model to evaluation mode
    sample_df = pd.read_csv(sample_csv)
    predictions = []
    
    with torch.no_grad(): # Disable gradient calculation for efficiency
        # Predict labels following the exact order of the sample CSV
        for filename in sample_df['filename']:
            img_path = os.path.join(test_img_dir, filename)
            img = Image.open(img_path).convert('RGB')
            img = transform(img).unsqueeze(0).to(device) # Prepare batch dimension
            
            output = model(img)
            _, predicted = torch.max(output, 1) # Pick the class with the highest probability
            predictions.append(predicted.item())
            
    # Save the final results to a CSV for Kaggle submission
    sample_df['category'] = predictions
    sample_df.to_csv('CNN_submission.csv', index=False)
    print("Submission file 'CNN_submission.csv' generated successfully!")

# %%
# --- Execution ---
train(epochs=10)

predict_and_save(
    test_img_dir='/kaggle/input/music-test/music_test',
    sample_csv='/kaggle/input/music-scale-recognition-by-cnn/sample_truth.csv'
)
